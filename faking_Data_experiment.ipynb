# %% [markdown]
# <a href="https://colab.research.google.com/github/nebyu08/data_sc/blob/main/faking_Data_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # using GPT-2

# %%
# !pip install gpt-2-simple -q
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
import  gpt_2_simple as gpt2
model_name="124M"
gpt2.download_gpt2(model_name=model_name)
sess=gpt2.start_tf_sess()
gpt2.load_gpt2(sess,model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 4.69Git/s]
# Fetching encoder.json: 1.05Mit [00:00, 2.79Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 4.80Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:12, 40.2Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 1.38Git/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 4.93Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 3.64Mit/s]
# Loading pretrained model models/124M/model.ckpt

# %%
#generate data
prompt="generate fake data about PTSD"
generate_text=gpt2.generate(sess,model_name=model_name,prefix=prompt,length=100,temperature=0.7,nsamples=1,batch_size=1,return_as_list=True)[0]

# %%
print(generate_text)
# Out:
# generate fake data about PTSD (as well as data about the duration of the PTSD) to improve the efficacy of training (by increasing the amount of training that will be done).
#
# The idea is that training (e.g., situational awareness training) can help reinforce the symptoms of PTSD and help the person in that situation to get better at focusing on the task at hand, in the same way that stress-management training can help people focus on their emotions. The idea is that training (e.g., situational awareness

# %%
print(generate_text)
# Out:
# generate fake data about PTSD (as well as data about the duration of the PTSD) to improve the efficacy of training (by increasing the amount of training that will be done).
#
# The idea is that training (e.g., situational awareness training) can help reinforce the symptoms of PTSD and help the person in that situation to get better at focusing on the task at hand, in the same way that stress-management training can help people focus on their emotions. The idea is that training (e.g., situational awareness

# %% [markdown]
# ## lets try PTSD

# %%
#generate data
prompt1="having PTSD IS"
generate_text=gpt2.generate(sess,model_name=model_name,prefix=prompt1,length=100,temperature=0.7,nsamples=1,batch_size=1,return_as_list=True)[0]
print(generate_text)
# Out:
# having PTSD IS MUCH MORE EFFORTIVE, not to mention it's easier to get into the situation.
#
# It's easy to get into the situation by taking a look at a website or forum. This type of site will provide you with a quick and easy way of getting prepared for a potential serious problem.
#
# You can also get involved with our training program. Our training is designed to teach you how to do everything in your power to get better at everything. This is one of those things that can

# %% [markdown]
# # llama generated

# %%
# !pip install  huggingface_hub -q

# %%
from huggingface_hub import  login
login(token="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")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install transformers -q

# %%
from transformers import  AutoModelForCausalLM,AutoTokenizer
model= AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf")
tokenizer=AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf")
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]

# %% [markdown]
# # other models/........Dolly...falcon...

# %%
# install dependencies
# !pip install transformers -q
# !pip install sentencepiece -q
# !pip install accelerate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 3.4 MB/s eta 0:00:00

# %%
import torch                        # allows Tensor computation with strong GPU acceleration
from transformers import pipeline   # fast way to use pre-trained models for inference
import os

# %%
# load model
dolly_pipeline = pipeline(model="databricks/dolly-v2-3b",
                            torch_dtype=torch.bfloat16,
                            trust_remote_code=True,
                            device_map="auto")
# Out:
# config.json:   0%|          | 0.00/819 [00:00<?, ?B/s]
# instruct_pipeline.py:   0%|          | 0.00/9.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/databricks/dolly-v2-3b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/5.68G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
# define helper function
def get_completion_dolly(input):
  system = f"""
     generate stories based on the title that is given to you and make a great story
  """
  prompt = f"#### System: {system}\n#### User: \n{input}\n\n#### Response from Dolly-v2-3b:"
  print(prompt)
  dolly_response = dolly_pipeline(prompt,
                                  max_new_tokens=500
                                  )
  return dolly_response[0]["generated_text"]

# %%
prompt="Living with anxiety feels like.."
print(get_completion_dolly(prompt))
# Out:
# #### System:
#      generate stories based on the title that is given to you and make a great story
#
# #### User:
# Living with anxiety feels like..
#
# #### Response from Dolly-v2-3b:
# ...

# %%
prompt="Living with PTSD feels like.."
print(get_completion_dolly(prompt))
# Out:
# #### System:
#      generate stories based on the title that is given to you and make a great story
#
# #### User:
# Living with PTSD feels like..
#
# #### Response from Dolly-v2-3b:
# Living with PTSD feels like war. PTSD is the permanent distress caused by exposure to traumatic experiences. The traumatic experiences could be natural disaster, car accident, homicide or any violent event. People who have suffered from PTSD have a number of common symptoms. One of the symptoms include recurrent and intrusive memories of the event, which can lead to flashbacks and problems with sleep and depression.
#
# Despite all the great advancements in modern medicine, the symptoms of PTSD still can’t be fully eliminated. There’s no physical wound that can be fixed. But what we can do is make up for it. We can do our best to avoid those who are related to traumatic events and try our best to put these distressing thoughts behind us.
#
# ...

# %%
# define helper function
def get_completion_dolly_2(input):
  system = f"""
     the prompt is going to give you a type ofpsychological disroder and you are going to generate stories of some one living with that disorder
  """
  prompt = f"#### System: {system}\n#### User: \n{input}\n\n#### Response from Dolly-v2-3b:"
  print(prompt)
  dolly_response = dolly_pipeline(prompt,
                                  max_new_tokens=500
                                  )
  return dolly_response[0]["generated_text"]

# %%
prompt="depression"
print(get_completion_dolly_2(prompt))
# Out:
# #### System:
#      the prompt is going to give you a type ofpsychological disroder and you are going to generate stories of some one living with that disorder
#
# #### User:
# depression
#
# #### Response from Dolly-v2-3b:
# I lived with depression for years. One day I was browsing through fashion magazines and that was it for me. I got my things and left immediately. I haven't spoken to any of my friends since and I stopped going to the beach. I think I'm on this end of Florida, if you can't tell.
#
# I'm going through my closets right now and it's a struggle not to just tear things to pieces. I don't know what to do with all of these clothes. I know I should donate them but I can't bring myself to throw them away. I keep thinking that some poor person will get a hold of these and they'll be warm and feel comforting on a cold winter's night.
#
# ...

# %%
prompt="OCD"
print(get_completion_dolly_2(prompt))
# Out:
# #### System:
#      the prompt is going to give you a type ofpsychological disroder and you are going to generate stories of some one living with that disorder
#
# #### User:
# OCD
#
# #### Response from Dolly-v2-3b:
# OCD  —  Obsessive Compulsive Disorder
# ...
